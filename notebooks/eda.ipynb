# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('F:/projectssss/iot-predictive-maintenance/data/raw/sensor_data.csv')

df.describe()

sns.lineplot(data=df[['temperature','vibration','pressure']]) # plot the sensor data to visualize trends and anomalies
plt.show()
